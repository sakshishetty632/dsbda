# %%
import pandas as pd
import io

# %%
df = pd.read_csv('adult_dataset.csv')

# %%
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %% [markdown]
# # Creating Subsets

# %%
subset1 = df[['workclass','race','income']].iloc[:1000]
subset2 = df[['gender','income']].iloc[:1000]

# %%
subset1
# Out:
#      workclass   race income
# 0      Private  Black  <=50K
# 1      Private  White  <=50K
# 2    Local-gov  White   >50K
# 3      Private  Black   >50K
# 4            ?  White  <=50K
# ..         ...    ...    ...
# 995    Private  White  <=50K
# 996  Local-gov  White  <=50K
# 997    Private  White  <=50K
# 998    Private  White  <=50K
# 999    Private  Black  <=50K
#
# [1000 rows x 3 columns]

# %%
subset2
# Out:
#      gender income
# 0      Male  <=50K
# 1      Male  <=50K
# 2      Male   >50K
# 3      Male   >50K
# 4    Female  <=50K
# ..      ...    ...
# 995  Female  <=50K
# 996  Female  <=50K
# 997    Male  <=50K
# 998    Male  <=50K
# 999    Male  <=50K
#
# [1000 rows x 2 columns]

# %% [markdown]
# # Merging

# %%
df_merged = pd.merge(subset1,subset2,on='income')

# %%
df_merged
# Out:
#        workclass   race income  gender
# 0        Private  Black  <=50K    Male
# 1        Private  Black  <=50K    Male
# 2        Private  Black  <=50K  Female
# 3        Private  Black  <=50K    Male
# 4        Private  Black  <=50K    Male
# ...          ...    ...    ...     ...
# 635195   Private  White   >50K    Male
# 635196   Private  White   >50K    Male
# 635197   Private  White   >50K    Male
# 635198   Private  White   >50K    Male
# 635199   Private  White   >50K  Female
#
# [635200 rows x 4 columns]

# %% [markdown]
# # Sort

# %%
df_sorted = df.sort_values(by='age')

# %%
df_sorted
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 32598   17           Private  133449           9th                5
# 29817   17  Self-emp-not-inc  181317          10th                6
# 36580   17           Private  147339          10th                6
# 26409   17           Private  186677          11th                7
# 19520   17                 ?  110998  Some-college               10
# ...    ...               ...     ...           ...              ...
# 12446   90           Private  347074  Some-college               10
# 19172   90           Private  171956  Some-college               10
# 8982    90           Private  225063       HS-grad                9
# 28277   90           Private   40388     Bachelors               13
# 899     90           Private  149069    Assoc-acdm               12
#
#            marital-status         occupation   relationship  \
# 32598       Never-married      Other-service      Own-child
# ...

# %% [markdown]
# # Transpose

# %%
df_transpose = df.transpose()

# %%
df_transpose
# Out:
#                              0                   1                   2      \
# age                             25                  38                  28
# workclass                  Private             Private           Local-gov
# fnlwgt                      226802               89814              336951
# education                     11th             HS-grad          Assoc-acdm
# educational-num                  7                   9                  12
# marital-status       Never-married  Married-civ-spouse  Married-civ-spouse
# occupation       Machine-op-inspct     Farming-fishing     Protective-serv
# relationship             Own-child             Husband             Husband
# race                         Black               White               White
# gender                        Male                Male                Male
# capital-gain                     0                   0                   0
# ...

# %% [markdown]
# # Shape and Reshape

# %%
df.shape
# Out:
# (48842, 15)

# %%
df1 = df[['age','workclass','gender','race','income']].iloc[:1000]

# %%
df_melt = pd.melt(df1,id_vars=['income'],var_name = 'metrics',value_name = 'values')

# %%
df_melt
# Out:
#      income metrics values
# 0     <=50K     age     25
# 1     <=50K     age     38
# 2      >50K     age     28
# 3      >50K     age     44
# 4     <=50K     age     18
# ...     ...     ...    ...
# 3995  <=50K    race  White
# 3996  <=50K    race  White
# 3997  <=50K    race  White
# 3998  <=50K    race  White
# 3999  <=50K    race  Black
#
# [4000 rows x 3 columns]
