# %%
import pandas as pd
df = pd.read_csv('dataset_Facebook.csv',sep=';')

# %%
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %% [markdown]
# # Creating Subsets

# %%
subset1 = df[['Type','Category','like','share']].loc[:150]

# %%
subset2 = df[['Type','Category','like','share']].loc[151:300]

# %%
subset1
# Out:
#        Type  Category    like  share
# 0     Photo         2    79.0   17.0
# 1    Status         2   130.0   29.0
# 2     Photo         3    66.0   14.0
# 3     Photo         2  1572.0  147.0
# 4     Photo         2   325.0   49.0
# ..      ...       ...     ...    ...
# 146   Photo         3   189.0   15.0
# 147   Photo         3    80.0   14.0
# 148  Status         2   148.0   28.0
# 149    Link         1    24.0   11.0
# 150   Photo         1   302.0   41.0
#
# [151 rows x 4 columns]

# %%
subset2
# Out:
#       Type  Category   like  share
# 151  Photo         2  166.0   32.0
# 152  Photo         2  358.0   49.0
# 153  Photo         1  161.0   25.0
# 154  Photo         2  319.0   55.0
# 155  Photo         2   54.0   16.0
# ..     ...       ...    ...    ...
# 296  Photo         3   93.0   19.0
# 297  Photo         3   62.0   10.0
# 298  Photo         2   78.0   16.0
# 299  Photo         1   14.0    1.0
# 300  Photo         2  231.0   43.0
#
# [150 rows x 4 columns]

# %% [markdown]
# # Merging

# %%
df_merged = pd.merge(subset1,subset2,how='outer')

# %%
df_merged
# Out:
#        Type  Category    like  share
# 0     Photo         2    79.0   17.0
# 1    Status         2   130.0   29.0
# 2     Photo         3    66.0   14.0
# 3     Photo         2  1572.0  147.0
# 4     Photo         2   325.0   49.0
# ..      ...       ...     ...    ...
# 295   Photo         3    93.0   19.0
# 296   Photo         3    62.0   10.0
# 297   Photo         2    78.0   16.0
# 298   Photo         1    14.0    1.0
# 299   Photo         2   231.0   43.0
#
# [300 rows x 4 columns]

# %% [markdown]
# # Sort

# %%
df_sort = df.sort_values(by='like',ascending=False,kind='quicksort')

# %%
df_sort
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 244            130791  Photo         2           7             3          5
# 379            111620  Photo         3           4             1         14
# 349            117764  Photo         3           5             5         13
# 168            135428  Photo         1           9             3         10
# 3              139441  Photo         2          12             2         10
# ..                ...    ...       ...         ...           ...        ...
# 21             138414  Photo         1          12             7         10
# 100            137020  Photo         1          10             4          9
# 441             98195  Photo         1           3             5          4
# 417            104070  Photo         1           3             3         10
# 111            136736  Photo         1          10             6          8
#
# ...

# %% [markdown]
# # Transpose

# %%
df_transpose = df.transpose()

# %%
df_transpose
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %% [markdown]
# # Shape and Reshape

# %%
df.shape
# Out:
# (500, 19)

# %%
dfs1 = pd.DataFrame(df,columns=['like','share','Category','Type'])

# %%
dfs1.head()
# Out:
#      like  share  Category    Type
# 0    79.0   17.0         2   Photo
# 1   130.0   29.0         2  Status
# 2    66.0   14.0         3   Photo
# 3  1572.0  147.0         2   Photo
# 4   325.0   49.0         2   Photo

# %%
df_pivot = pd.pivot_table(dfs1,index=['Category','like'])

# %%
df_pivot
# Out:
#                       share
# Category like
# 1        0.0       0.000000
#          1.0       2.000000
#          2.0       0.000000
#          3.0       0.666667
#          4.0       1.000000
# ...                     ...
# 3        1155.0  102.000000
#          1372.0   47.000000
#          1546.0  181.000000
#          1639.0  122.000000
#          1998.0  128.000000
#
# [368 rows x 1 columns]

# %%
df_pivot.reset_index(inplace=True)

# %%
df_pivot
# Out:
#      Category    like       share
# 0           1     0.0    0.000000
# 1           1     1.0    2.000000
# 2           1     2.0    0.000000
# 3           1     3.0    0.666667
# 4           1     4.0    1.000000
# ..        ...     ...         ...
# 363         3  1155.0  102.000000
# 364         3  1372.0   47.000000
# 365         3  1546.0  181.000000
# 366         3  1639.0  122.000000
# 367         3  1998.0  128.000000
#
# [368 rows x 3 columns]

# %%
df_melt = df_pivot.melt(id_vars=['like','share'])

# %%
df_melt
# Out:
#        like       share  variable  value
# 0       0.0    0.000000  Category      1
# 1       1.0    2.000000  Category      1
# 2       2.0    0.000000  Category      1
# 3       3.0    0.666667  Category      1
# 4       4.0    1.000000  Category      1
# ..      ...         ...       ...    ...
# 363  1155.0  102.000000  Category      3
# 364  1372.0   47.000000  Category      3
# 365  1546.0  181.000000  Category      3
# 366  1639.0  122.000000  Category      3
# 367  1998.0  128.000000  Category      3
#
# [368 rows x 4 columns]

# %%
df_melt.shape
# Out:
# (368, 4)
